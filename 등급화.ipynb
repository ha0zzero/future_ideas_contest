# %%
# !pip install koreanize-matplotlib

# %%
# !pip install statsmodels

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
df= pd.read_excel('./merge_data.xlsx')
df
# Out:
#    Seoul_GU  Metro_count  Drinking_fountain  Bus_count     settled_pp  \
# 0       강남구           33                 64        560  536668.736842
# 1       강동구           13                 71        407  432868.631579
# 2       강북구           13                 51        412  313156.894737
# 3       강서구           22                 52        621  585962.789474
# 4       관악구            4                 70        488  495869.894737
# 5       광진구           11                 68        293  347659.894737
# 6       구로구           14                 43        513  402254.631579
# 7       금천구            4                 49        357  229218.263158
# 8       노원구           17                 67        520  535525.789474
# 9       도봉구            8                 50        369  331842.947368
# 10     동대문구           14                 49        319  338433.157895
# 11      동작구           16                 80        456  390846.157895
# ...

# %%
df.set_index("Seoul_GU", inplace=True)
df.head()
# Out:
#           Metro_count  Drinking_fountain  Bus_count     settled_pp  \
# Seoul_GU
# 강남구                33                 64        560  536668.736842
# 강동구                13                 71        407  432868.631579
# 강북구                13                 51        412  313156.894737
# 강서구                22                 52        621  585962.789474
# 관악구                 4                 70        488  495869.894737
#
#              local_pp  Public_sports_count  single_residential_area  \
# Seoul_GU
# 강남구       838299.2436                   36              1148617.993
# 강동구       506931.6248                   43              1581978.067
# 강북구       298129.8057                   16              2214955.471
# 강서구       553532.9093                   48              1819662.074
# 관악구       497153.1916                   26              3174496.906
#
#           communal_residential_area  administrative_area  commercial_area  \
# Seoul_GU
# ...

# %% [markdown]
# ##### 상주인구 데이터

# %%
df["settled_pp"].sort_values().plot(kind="barh", grid=True, title="상주인구 많은 구", figsize=(10, 10))
# Out:
# <Axes: title={'center': '상주인구 많은 구'}, ylabel='Seoul_GU'>

# %% [markdown]
# ##### 생활인구 데이터

# %%
df["local_pp"].sort_values().plot(kind="barh", grid=True, title="생활인구 많은 구", figsize=(10, 10))
# Out:
# <Axes: title={'center': '생활인구 많은 구'}, ylabel='Seoul_GU'>

# %% [markdown]
# ##### 버스정류장 데이터

# %%
df["Bus_count"].sort_values().plot(kind="barh", grid=True, title="버스정류장 많은 구", figsize=(10, 10))
# Out:
# <Axes: title={'center': '버스정류장 많은 구'}, ylabel='Seoul_GU'>

# %% [markdown]
# ##### 등급화

# %%
grade=pd.read_excel('./등급화_점수_간격.xlsx', skiprows=1)
grade
# Out:
#       구분      10       9       8       7       6       5       4       3  \
# 0   상주인구  10만 이상  20만 이상  25만 이상  30만 이상  35만 이상  40만 이상  45만 이상  50만 이상
# 1   생활인구  20만 이상  30만 이상  35만 이상  40만 이상  45만 이상  50만 이상  55만 이상  60만 이상
# 2  버스정류장  200 이상  250 이상  300 이상  350 이상  400 이상  450 이상  500 이상  550 이상
#
#         2       1
# 0  55만 이상  60만 이상
# 1  70만 이상  80만 이상
# 2  600 이상  650 이상

# %% [markdown]
# ##### 참고 레퍼런스
# - 유창호, 이왕무, 박성현, & 신승식. (2017). 공공시설물의 적정입지 선정에 관한 연구. 한국지적정보학회지, 19(3), 151-162.
# - 박환용, 정일훈, & 김철중. (2010). 도시공공시설의 적정입지 선정에 관한 연구: 파주시를 중심으로. 국토연구, 149-168.
# - 이신훈. (2008). 공공시설 입지선정을 위한 입지모델 구축 및 적용에 관한 연구-금산군 문화시설을 중심으로.
